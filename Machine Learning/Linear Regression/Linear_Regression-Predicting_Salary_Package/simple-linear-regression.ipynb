# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
data= pd.read_csv("placement.csv")

data.head(5)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
data.shape
# Out:
# (200, 2)

# %%
#scatter plot with simplet matplot code


plt.scatter(x=data['cgpa'],y=data['package'])
plt.xlabel=('cgpa')
plt.ylabel('package   (in L.P.A)')
plt.show()

# %%
#scatter plot with simplet matplot code

sns.scatterplot(data=data, x=data['cgpa'],y=data['package'])
plt.show()

# %% [markdown]
# ## Split data

# %%
# x= input column
#y= output 


X=data.iloc[:,:1]
y=data.iloc[:,:2]

# %%
print(X)
print(y)
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
#      cgpa  package
# 112  8.58     4.10
# 29   7.15     3.49
# 182  5.88     2.08
# 199  6.22     2.33
# 193  4.57     1.94
# 85   4.79     1.48
# 10   5.32     1.86
# 54   6.86     3.09
# 115  8.35     4.21
# 35   6.87     2.87
# 12   8.94     3.65
# 92   7.90     4.00
# 13   6.93     2.89
# 126  5.91     2.60
# 174  7.32     2.99
# 2    7.82     3.25
# 44   5.09     1.86
# 3    7.42     3.67
# 113  6.94     2.37
# 14   7.73     3.42
# 23   6.19     2.48
# 25   7.28     3.65
# 6    6.73     2.60
# 134  7.20     2.83
# 165  8.21     4.08
# 173  6.75     2.56
# 45   7.87     3.58
# 65   7.60     3.81
# 48   8.63     4.09
# 122  5.12     2.01
# 178  8.15     3.63
# 64   7.36     2.92
# 9    8.31     3.51
# 57   6.60     1.94
# 78   6.59     2.21
# 71   7.47     3.34
# 128  7.93     3.34
# 176  6.29     3.23
# 131  6.37     2.01
# 53   6.47     2.61

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[8.58      , 3.89111601]])

# %%
plt.scatter(x=data['cgpa'],y=data['package'])
plt.plot(X_train,lr.predict(X_train))
plt.xlabel=('cgpa')
plt.ylabel('package   (in L.P.A)')
# Out:
# Text(0, 0.5, 'package   (in L.P.A)')

# %% [markdown]
# # Mathematic Equation

# %% [markdown]
# Line equation
#
# ## y=mx+b

# %% [markdown]
# ## Slop Value
#
# lr.coef_

# %%
m = lr.coef_

# %% [markdown]
# ## Intersect value

# %%
b = lr.intercept_

# %%
# y = mx + b

m *8.58 + b
# Out:
# array([[8.58      , 7.68388808],
#        [4.78722793, 3.89111601]])
